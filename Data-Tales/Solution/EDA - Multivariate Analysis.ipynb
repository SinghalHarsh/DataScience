# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
from matplotlib import rcParams
#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (8, 3)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\matplotlib\__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
train = pd.read_csv('modified_train.csv', parse_dates=['Day.Index'], dayfirst=True)
test = pd.read_csv('modified_test.csv', parse_dates=['Day.Index'], dayfirst=True)
data = pd.read_csv('modified_data.csv', parse_dates=['Day.Index'], dayfirst=True)

# %%
train[["Impressions","Obtained.Leads"]].head()
# Out:
#    Impressions  Obtained.Leads
# 0        13930              20
# 1        11177              18
# 2        12968              13
# 3        13850              26
# 4        12346              18

# %%
a=train.corr()

# %%
a["Obtained.Leads"].sort_values()
# Out:
# Avg. Bounce.Rate   -0.069736
# Year               -0.015586
# Day_Of_Week         0.004812
# Day                 0.069612
# Avg.Position        0.214029
# Week                0.430885
# SpecialDay          0.439720
# Month               0.477446
# Day_Of_Year         0.483652
# Campaign            0.515570
# Total.Revenue       0.516719
# CTR                 0.579410
# Avg.Time.Page       0.608129
# Min.CPC             0.653066
# Max.CPC             0.723661
# Target.Clicks       0.752013
# Returning.Users     0.779850
# Targeted.Leads      0.782695
# Impressions         0.782788
# Obt.Click           0.802314
# Amount.Spend        0.805239
# Obtained.Leads      1.000000
# Name: Obtained.Leads, dtype: float64

# %%
train.columns
# Out:
# Index(['Day.Index', 'Campaign', 'Impressions', 'Target.Clicks', 'Obt.Click',
#        'Min.CPC', 'Max.CPC', 'CTR', 'Amount.Spend', 'Returning.Users',
#        'Targeted.Leads', 'SpecialDay', 'Avg. Bounce.Rate', 'Avg.Time.Page',
#        'Avg.Position', 'Total.Revenue', 'Obtained.Leads', 'Year', 'Month',
#        'Week', 'Day_Of_Week', 'Day', 'Day_Of_Year'],
#       dtype='object')

# %%
# Time

# %%
x=train[train.Month<5]

# %%
sns.boxplot(y=x['Obtained.Leads'], x=x['Year'],)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a087f3cae7d> in <module>()
# ----> 1 sns.boxplot(y=x['Obtained.Leads'], x=x['Year'],)
#
# NameError: name 'sns' is not defined

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Year'])

# %%
sns.boxplot(y=x['Obtained.Leads'], x=x['Month'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Month'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Week'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Day'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Day_Of_Week'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Day_Of_Year'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['SpecialDay'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Avg.Position'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Min.CPC'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Max.CPC'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Campaign'])

# %%
train["Obtained.Leads"].describe()
# Out:
# count    820.000000
# mean      14.921951
# std        7.588067
# min        3.000000
# 25%        9.000000
# 50%       13.000000
# 75%       19.000000
# max       47.000000
# Name: Obtained.Leads, dtype: float64

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Target.Clicks'])

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Obt.Click'])

# %%
plt.scatter(train['Impressions'], train['Obtained.Leads'])

# %%
train["Y"]=train.index

# %%
rcParams['figure.figsize'] = (18, 6)

# %%
train["Obtained.Leads"][train["Obtained.Leads"]>40]=40
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
train["Obtained.Leads"][train.Month==12].describe()
# Out:
# count    62.000000
# mean     28.016129
# std       6.700849
# min      17.000000
# 25%      23.000000
# 50%      28.000000
# 75%      32.750000
# max      47.000000
# Name: Obtained.Leads, dtype: float64

# %%
9.75*1.5+32.75
# Out:
# 47.375

# %%
train.shape
# Out:
# (820, 24)

# %%
for i in range(1,13):
    remove(i)
# Out:
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# C:\Users\HARSH\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# Series([], Name: Obtained.Leads, dtype: float64)
# ...

# %%
def remove(k):
    x=train["Obtained.Leads"][train.Month==k]
    IQR =np.percentile(x,q=75)-np.percentile(x,q=25)
    d=np.percentile(x,q=75)+1.2*IQR
    print(train["Obtained.Leads"][(train.Month==k) & (train["Obtained.Leads"]>d)])
    train["Obtained.Leads"][(train.Month==k) & (train["Obtained.Leads"]>d)]=d
    print(train["Obtained.Leads"][(train.Month==k) & (train["Obtained.Leads"]>d)])

# %%
train["Y"]=train.index
k=train[train.SpecialDay==1]
sns.lmplot(x="Day_Of_Year", y="Obtained.Leads", data=k,hue="Year",fit_reg=False,size=4,aspect=2)

# %%
train["Y"]=train.index
sns.lmplot(x="Y", y="Obtained.Leads", data=train,hue="Month",fit_reg=False,size=4,aspect=2)

# %%
train["Y"]=train.index
sns.lmplot(x="Y", y="Obtained.Leads", data=train,hue="Month",fit_reg=False,size=4,aspect=2)

# %%
sns.lmplot(x="Y", y="Obtained.Leads", data=train,hue="Month",fit_reg=False,size=4,aspect=2)

# %%
sns.lmplot(x="Impressions", y="Obtained.Leads", data=train,hue="Avg.Position",fit_reg=False)

# %%
test["Impressions"].max()

# %%
train["Impressions"].max()

# %%
plt.scatter(train['Obt.Click'], train['Obtained.Leads'],)

# %%
sns.lmplot(x="Obt.Click", y="Obtained.Leads", data=train,hue="SpecialDay")

# %%
plt.scatter(train['CTR'], train['Obtained.Leads'])

# %%
plt.scatter(train['Amount.Spend'], train['Obtained.Leads'])

# %%
plt.scatter(train['Returning.Users'], train['Obtained.Leads'])

# %%
sns.lmplot(x="Targeted.Leads", y="Obtained.Leads", data=train,hue="SpecialDay")

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['Targeted.Leads'])

# %%
a=train["Targeted.Leads"].value_counts()

# %%
a.sort(inplace=True)

# %%
a

# %%
plt.scatter(train['Avg. Bounce.Rate'], train['Obtained.Leads'])

# %%
a=data[["Campaign","Target.Clicks","Min.CPC","Max.CPC"]]

# %%
a.groupby(["Campaign"]).mean()

# %%
def function1(X):
    return int(round(X["Amount.Spend"]/X["Obt.Click"]))

# %%
data["CPC"]=data.apply(function1,axis=1)
train["CPC"]=train.apply(function1,axis=1)
test["CPC"]=test.apply(function1,axis=1)

# %%
data.head(1)

# %%
sns.boxplot(y=train['Obtained.Leads'], x=train['CPC'])

# %%
train["CPC"].unique()

# %%
int(round(29.6))

# %%
def cate_plot(X):
    rcParams['figure.figsize'] = (8, 3)
    fig, (ax1, ax2, ax3) = plt.subplots(1,3)
    sns.countplot(X,data=train,ax=ax1,)
    ax1.set_title('Train')
    sns.countplot(X,data=test,ax=ax2)
    ax2.set_title('Test')
    sns.countplot(X,data=data,ax=ax3)
    ax3.set_title('Data')
cate_plot("CPC")

# %%
#no
