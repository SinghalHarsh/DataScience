# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
from matplotlib import rcParams
#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (8, 3)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\matplotlib\__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
train = pd.read_csv('modified_train.csv', parse_dates=['Day.Index'], dayfirst=True)
test = pd.read_csv('modified_test.csv', parse_dates=['Day.Index'], dayfirst=True)
data = pd.read_csv('modified_data.csv', parse_dates=['Day.Index'], dayfirst=True)

# %%
data.head()
# Out:
#    Unnamed: 0  Amount.Spend  Avg. Bounce.Rate  Avg.Position  Avg.Time.Page  \
# 0           0          6200             70.81             5            571
# 1           1          8352             32.38             3            447
# 2           2          5908             99.01             1            322
# 3           3          6664             43.60             2            534
# 4           4          7511             23.24             8            481
#
#     CTR  Campaign  Day  Day.Index  Day_Of_Week  ...   Month  Obt.Click  \
# 0  1.44         1    1 2013-01-01            1  ...       1        200
# 1  2.58         1    2 2013-01-02            2  ...       1        288
# 2  1.63         1    3 2013-01-03            3  ...       1        211
# 3  1.72         1    4 2013-01-04            4  ...       1        238
# 4  2.10         1    5 2013-01-05            5  ...       1        259
#
#    Obtained.Leads  Returning.Users  SpecialDay  Target.Clicks  Targeted.Leads  \
# ...

# %%
#Univariate_Analysis

# %%
def cont_plot(X):
    rcParams['figure.figsize'] = (8, 6)
    fig, arr = plt.subplots(2,2)
    sns.distplot(train[X],ax=arr[0,0])
    arr[0,0].set_title('Train')
    sns.distplot(test[X],ax=arr[0,1])
    arr[0,1].set_title('Test')
    sns.distplot(data[X],ax=arr[1,0])
    arr[1,0].set_title('Data')

# %%
def cate_plot(X):
    rcParams['figure.figsize'] = (8, 3)
    fig, (ax1, ax2, ax3) = plt.subplots(1,3)
    sns.countplot(X,data=train,ax=ax1,)
    ax1.set_title('Train')
    sns.countplot(X,data=test,ax=ax2)
    ax2.set_title('Test')
    sns.countplot(X,data=data,ax=ax3)
    ax3.set_title('Data')

# %%
# 1. Compaign

# %%
cate_plot("Campaign")

# %%
# 2 Impressions

# %%
cont_plot("Impressions")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# 3. Targeted Clicks

# %%
train["Target.Clicks"].value_counts()
# Out:
# 170    215
# 145    184
# 225    177
# 375    122
# 310    122
# Name: Target.Clicks, dtype: int64

# %%
train["Campaign"].value_counts()
# Out:
# 2    215
# 3    184
# 1    177
# 5    122
# 4    122
# Name: Campaign, dtype: int64

# %%
cate_plot("Target.Clicks")

# %%
# 4. Obtained Clicks

# %%
cont_plot("Obt.Click")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# 5. Minimum CPC

# %%
data["Min.CPC"].value_counts()
# Out:
# 26    368
# 29    366
# 25    276
# 28    237
# Name: Min.CPC, dtype: int64

# %%
cate_plot("Min.CPC")

# %%
# 5. Maximum CPC

# %%
cate_plot("Max.CPC")

# %%
# 5. CTR

# %%
plot("CTR")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Amount Spend

# %%
plot("Amount.Spend")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Returning Users

# %%
cont_plot("Returning.Users")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#Special Day

# %%
data.SpecialDay.value_counts()
# Out:
# 0    1130
# 1     117
# Name: SpecialDay, dtype: int64

# %%
cate_plot("SpecialDay")

# %%
# Bounce Rate

# %%
cont_plot("Avg. Bounce.Rate")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Average Time Page

# %%
cont_plot("Avg.Time.Page")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Average Position

# %%
data["Avg.Position"].value_counts()
# Out:
# 3    251
# 4    226
# 2    210
# 5    194
# 1    158
# 6    102
# 7     76
# 8     30
# Name: Avg.Position, dtype: int64

# %%
cate_plot("Avg.Position")

# %%
# Total Revenue

# %%
cont_plot("Total.Revenue")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Targeted Leads

# %%
cont_plot("Targeted.Leads")
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Obtained Lead

# %%
rcParams['figure.figsize'] = (8, 6)
sns.distplot(train["Obtained.Leads"])
# Out:
# C:\Users\HARSH\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#n0
